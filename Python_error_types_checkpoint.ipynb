# %% [markdown]
# # Rectify the code in each cell and **explain the error in comments**

# %% [markdown]
# ### index error

# %%
mylist=[14, "hello", 967]
print(mylist)
#mylist[6]
# Out:
# [14, 'hello', 967]

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # syntax error

# %%
print("python errors")
# Out:
# python errors

# %% [markdown]
# # key error

# %%
mydictionnary={True:"hello",False:"bye", '3':"python"}
mydictionnary=('[True]'0])
# Out:
#   File "<ipython-input-28-dd24a9ba29d4>", line 2
#     mydictionnary=('[True]'0])
#                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# # indentation error

# %%
i=14
while i<78:
  print(i)
i+=1
# Out:
# Streaming output truncated to the last 5000 lines.
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# ...

# %% [markdown]
# # StopIteration

# %%
it = int (1)

# %% [markdown]
# # TypeError

# %%
15+15
# Out:
# 30

# %% [markdown]
# # ValueError

# %%
str('python')
# Out:
# 'python'

# %% [markdown]
# # NameError

# %%
"python"
# Out:
# 'python'

# %% [markdown]
# # ZeroDivisionError

# %%
x=19/1
